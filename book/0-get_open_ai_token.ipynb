# %% [markdown]
# # Get your OpenAI token
# This token is only active during the workshop session this morning.

# %%
import base64
import os
from cryptography.fernet import Fernet
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.primitives.kdf.pbkdf2 import PBKDF2HMAC
from getpass import getpass

# %%
password = getpass(prompt='Enter your Password:').encode()
salt = b'\x86;e\x8e\nr\xe7I\xcb\x924[\xd5\xf8o/'
kdf = PBKDF2HMAC(
    algorithm=hashes.SHA256(),
    length=32,
    salt=salt,
    iterations=480000,
)
key = base64.urlsafe_b64encode(kdf.derive(password))
f = Fernet(key)

# %%
encrypted_data = 'gAAAAABm687lC-BFZEzabcDPgl9t_i8pW9IbAkYLHzTv1A_ivpIHpNTHBy83JZ2k1i_YxLAf7mvirIJuuh7zloij9acQjFRK9HZGBclvVFZrY9-u7oCPpFJ_DpBTPg8kywZOsvoIjRp4JlwGTA0utrkQiHyWVneVMZO1ZtpGWBW-Mo8nuA9yEhkkAyRVDH-J3BsflqMuovZw'

# %% [markdown]
# ## Copy your OpenAI token below

# %%
f.decrypt(encrypted_data.encode()).decode()
